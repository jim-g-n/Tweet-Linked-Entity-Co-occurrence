# %% [markdown]
# # Entity Co-occurrence Graph Analysis

# %% [markdown]
# This notebook analyses and compares the different graphs created using the FEL and DBpedia Spotlight algorithms. In the interest of space, the associated paper only analyses FEL graphs with -2 to -3 confidence and DBpedia Spotlight graphs with 0.5 to 0.9 confidence, but other graphs are also possible.

# %%
from graph_tool import Graph
import graph_tool.all as gt
import pandas as pd
from itertools import combinations
from matplotlib import pyplot as plt
import numpy as np
from collections import Counter
from itertools import zip_longest
import ast
import pickle

# %%
def get_main_graph_prop(g):
    num_vertices = g.num_vertices()
    num_edges = g.num_edges()
    average_degree = num_edges/num_vertices
    
    weighted_degree_arr = g.get_total_degrees(g.get_vertices(), eweight = g.edge_properties['weight'])
    average_weighted_degree = weighted_degree_arr.sum()/num_vertices

    u = gt.extract_largest_component(g)
    size_largest_comp = u.num_vertices()

    pd, ep = gt.pseudo_diameter(g)

    return num_vertices, num_edges, pd, average_degree, average_weighted_degree, size_largest_comp

def calc_ave_graph_values(g):
    local_clust = gt.vertex_average(g, gt.local_clustering(g))
    global_clust = gt.global_clustering(g)
    weighted_assort = gt.assortativity(g, "total", eweight = g.edge_properties['weight'])
    unweighted_assort = gt.assortativity(g, "total")

    return local_clust, global_clust, weighted_assort, unweighted_assort

def get_top_degree_nodes(g, reverse_entity_mapping, N = 10):
    vertex_arr = g.get_vertices()
    
    unweighted_degrees_arr = g.get_total_degrees(vertex_arr)
    weighted_degrees_arr = g.get_total_degrees(vertex_arr, eweight = g.edge_properties['weight'])
    
    sorted_unweighted_degree = vertex_arr[np.argsort(unweighted_degrees_arr)][::-1]
    sorted_weighted_degree = vertex_arr[np.argsort(weighted_degrees_arr)][::-1]
    
    top_unweighted = dict(zip([reverse_entity_mapping[k] for k in sorted_unweighted_degree[0:N]],np.sort(unweighted_degrees_arr)[::-1][0:N]))
    top_weighted = dict(zip([reverse_entity_mapping[k] for k in sorted_weighted_degree[0:N]],np.sort(weighted_degrees_arr)[::-1][0:N]))

    return top_weighted, top_unweighted

def get_top_pagerank_nodes(g, reverse_entity_mapping, N = 10):
    unweighted_pr = gt.pagerank(g).get_array()
    weighted_pr = gt.pagerank(g, weight = g.edge_properties['weight']).get_array()

    sorted_unweighted_pr = np.argsort(unweighted_pr)[::-1]
    sorted_weighted_pr = np.argsort(weighted_pr)[::-1]

    top_unweighted = dict(zip([reverse_entity_mapping[k] for k in sorted_unweighted_pr[0:N]],np.sort(unweighted_pr)[::-1][0:N]))
    top_weighted = dict(zip([reverse_entity_mapping[k] for k in sorted_weighted_pr[0:N]],np.sort(weighted_pr)[::-1][0:N]))

    return top_weighted, top_unweighted

def get_top_edges(g, reverse_entity_mapping, N = 10):
    edge_arr = g.get_edges([g.edge_properties['weight']])

    ind=np.argsort(edge_arr[:,-1])
    b=edge_arr[ind]

    return list(zip([reverse_entity_mapping[k] for k in b[:,0][-N:]], [reverse_entity_mapping[k] for k in b[:,1][-N:]]))

# %%
def plot_log_deg_dist(g, axis, weighted = False, **kwargs):
    if weighted:
        degrees_arr = g.get_total_degrees(g.get_vertices(), eweight = g.edge_properties['weight'])
    else:
        degrees_arr = g.get_total_degrees(g.get_vertices())

    fun_vals = sorted(np.log10(degrees_arr))

    sorted_values = Counter(fun_vals).keys()
    cumulative_counts = (np.cumsum(list(Counter(fun_vals).values()))/len(fun_vals))

    axis.plot(sorted_values, cumulative_counts, **kwargs)

# %%
directory = 'created_graphs/'

# %%
def create_graphs_dicts(annotation_tool, conf_list):
    full_graphs_dict = dict()

    for conf in conf_list:
        g = gt.load_graph(directory + annotation_tool + "_all_full_conf_" + conf + ".gt.gz")
    
        with open(directory + annotation_tool + '_all_full_conf_' + conf + '_data.pickle', 'rb') as handle:
            g_info = pickle.load(handle)
        full_graphs_dict[conf] = (g, g_info)

    conn_graphs_dict = dict()

    for conf in conf_list:
        g = gt.load_graph(directory + annotation_tool + "_all_conn_conf_" + conf + ".gt.gz")
    
        with open(directory + annotation_tool + '_all_conn_conf_' + conf + '_data.pickle', 'rb') as handle:
            g_info = pickle.load(handle)
        conn_graphs_dict[conf] = (g, g_info[0])

    return full_graphs_dict, conn_graphs_dict

# %% [markdown]
# ### Graph Loading

# %%
annotation_tool = 'fel'
#conf_list = ['1', '1.25', '1.5', '1.75', '2', '2.25', '2.5', '2.75', '3']
conf_list = ['2', '2.25', '2.5', '2.75', '3']
fel_full_graphs, fel_conn_graphs = create_graphs_dicts(annotation_tool, conf_list)

# %%
annotation_tool = 'dbpedia'
#conf_list = ['0.3', '0.4', '0.5', '0.6', '0.7', '0.8', '0.9']
conf_list = ['0.5', '0.6', '0.7', '0.8', '0.9']
db_full_graphs, db_conn_graphs = create_graphs_dicts(annotation_tool, conf_list)

# %% [markdown]
# ### Entity Similarity Plotting

# %%
def jaccard_similarity(list1, list2):
    intersection = len(list(set(list1).intersection(list2)))
    union = (len(set(list1)) + len(set(list2))) - intersection
    return float(intersection) / union

all_sims = []
for fel_conf in ['3', '2.75', '2.5', '2.25', '2']:
    fel_entities = list(fel_full_graphs[fel_conf][1][0].values())
    node_similarity = []
    for conf in db_full_graphs:
        db_entities = list(db_full_graphs[conf][1][0].values())
        node_similarity.append(jaccard_similarity(fel_entities, db_entities))
    all_sims.append([fel_conf, node_similarity])

for sim_vals in all_sims:
    plt.scatter(db_full_graphs.keys(), sim_vals[1], label = '-' + sim_vals[0])
plt.xlabel('DBpedia Spotlight confidence')
plt.ylabel('Jaccard similarity')
plt.legend(title = 'FEL confidence')

# %%
db_values = list(db_full_graphs['0.5'][1][0].keys())
fel_values = list(fel_full_graphs['3'][1][0].keys())

overlap = set(fel_values) & set(db_values)

print('Total FEL entities: ' + str(len(fel_values)))
print('Total DB entities: ' + str(len(db_values)))
print('Overlap: ' + str(len(overlap)) + ' (' + str(len(overlap)/len(fel_values)) + ' of FEL entities)')
# Out:
# Total FEL entities: 535572
# Total DB entities: 515022
# Overlap: 322756 (0.6026379273001576 of FEL entities)

# %% [markdown]
# ### Full Graphs Properties

# %%
index = ['num nodes', 'num edges', 'pseudo diameter', 'average degree', 'average weighted degree', 'largest component']

# %%
fel_main_prop_df = pd.DataFrame(columns = index)
for graph in fel_full_graphs:
    fel_main_prop_df = pd.concat([fel_main_prop_df, pd.Series(get_main_graph_prop(fel_full_graphs[graph][0]), index=index).to_frame().T], axis = 0)
fel_main_prop_df['conf'] = fel_full_graphs.keys()
fel_main_prop_df['conf'] = fel_main_prop_df['conf'].apply(lambda x: -float(x))

# %%
db_main_prop_df = pd.DataFrame(columns = index)
for graph in db_full_graphs:
    db_main_prop_df = pd.concat([db_main_prop_df, pd.Series(get_main_graph_prop(db_full_graphs[graph][0]), index=index).to_frame().T], axis = 0)
db_main_prop_df['conf'] = db_full_graphs.keys()

# %%
fel_main_prop_df['perc_largest_comp'] = fel_main_prop_df['largest component']/fel_main_prop_df['num nodes']
db_main_prop_df['perc_largest_comp'] = db_main_prop_df['largest component']/db_main_prop_df['num nodes']

# %%
cols = fel_main_prop_df.columns.tolist()
cols = cols[-1:] + cols[:-1]
fel_main_prop_df = fel_main_prop_df[cols]

fel_main_prop_df = fel_main_prop_df.iloc[::-1]

cols = db_main_prop_df.columns.tolist()
cols = cols[-1:] + cols[:-1]
db_main_prop_df = db_main_prop_df[cols]

# %%
fel_main_prop_df
# Out:
#    perc_largest_comp  num nodes   num edges  pseudo diameter  average degree  \
# 0           0.912120   535572.0  10019969.0              9.0       18.708911
# 0           0.890213   496670.0   7539889.0             10.0       15.180883
# 0           0.860775   456268.0   5496269.0             10.0       12.046142
# 0           0.820077   409826.0   3846504.0             11.0        9.385700
# 0           0.777433   357385.0   2594176.0             12.0        7.258771
#
#    average weighted degree  largest component  conf
# 0                93.087906           488506.0 -3.00
# 0                75.774542           442142.0 -2.75
# 0                60.685921           392744.0 -2.50
# 0                46.826609           336089.0 -2.25
# 0                36.581893           277843.0 -2.00

# %%
db_main_prop_df
# Out:
#    perc_largest_comp  num nodes   num edges  pseudo diameter  average degree  \
# 0           0.981174   515022.0  14113950.0              6.0       27.404557
# 0           0.971591   473225.0   8975858.0              6.0       18.967421
# 0           0.886125   435409.0   5855384.0              9.0       13.448009
# 0           0.854251   401286.0   4176344.0              9.0       10.407400
# 0           0.816466   358632.0   2920492.0             10.0        8.143423
#
#    average weighted degree  largest component conf
# 0               240.852954           505326.0  0.5
# 0               175.568362           459781.0  0.6
# 0                76.201861           385827.0  0.7
# 0                57.616184           342799.0  0.8
# 0                44.245739           292811.0  0.9

# %% [markdown]
# ### Full Graphs Plots

# %%
joint_conf_list = ['-3 / 0.5', '-2.75 / 0.6', '-2.5 / 0.7', '-2.25 / 0.8', '-2.00 / 0.9']

# %%
fig = plt.figure(figsize=(10,5))
ax = fig.add_subplot(111)    
ax1 = fig.add_subplot(121)
ax2 = fig.add_subplot(122)

ax.spines['top'].set_color('none')
ax.spines['bottom'].set_color('none')
ax.spines['left'].set_color('none')
ax.spines['right'].set_color('none')
ax.tick_params(labelcolor='w', top=False, bottom=False, left=False, right=False)

ax1.scatter(joint_conf_list, fel_main_prop_df['num nodes'], label = 'FEL')
ax1.scatter(joint_conf_list, db_main_prop_df['num nodes'], label = 'DBPedia Spotlight')
#axs[0].ylabel('fds')

ax2.scatter(joint_conf_list, fel_main_prop_df['perc_largest_comp'], label = 'FEL')
ax2.scatter(joint_conf_list, db_main_prop_df['perc_largest_comp'], label = 'DBPedia Spotlight')
ax2.legend()

ax1.set_ylabel("Number of nodes", fontsize = 13)
ax2.set_ylabel("Percentage largest component", fontsize = 13)
ax.set_xlabel('Confidence', fontsize = 13, labelpad = 20)
fig.tight_layout()

# %% [markdown]
# ### Connected Graphs Properties

# %%
fel_conn_prop_df = pd.DataFrame(columns = index)
for graph in fel_conn_graphs:
    fel_conn_prop_df = pd.concat([fel_conn_prop_df, pd.Series(get_main_graph_prop(fel_conn_graphs[graph][0]), index=index).to_frame().T], axis = 0)
fel_conn_prop_df['conf'] = fel_conn_graphs.keys()
fel_conn_prop_df['conf'] = fel_conn_prop_df['conf'].apply(lambda x: -float(x))

# %%
db_conn_prop_df = pd.DataFrame(columns = index)
for graph in db_conn_graphs:
    db_conn_prop_df = pd.concat([db_conn_prop_df, pd.Series(get_main_graph_prop(db_conn_graphs[graph][0]), index=index).to_frame().T], axis = 0)
db_conn_prop_df['conf'] = db_conn_graphs.keys()

# %%
cols = fel_conn_prop_df.columns.tolist()
cols = cols[-1:] + cols[:-1]
fel_conn_prop_df = fel_conn_prop_df[cols]

fel_conn_prop_df = fel_conn_prop_df.iloc[::-1]

cols = db_conn_prop_df.columns.tolist()
cols = cols[-1:] + cols[:-1]
db_conn_prop_df = db_conn_prop_df[cols]

# %%
fel_conn_prop_df
# Out:
#    conf  num nodes   num edges  pseudo diameter  average degree  \
# 0 -3.00   488506.0  10017512.0              9.0       20.506426
# 0 -2.75   442142.0   7536960.0             10.0       17.046469
# 0 -2.50   392744.0   5492703.0             10.0       13.985454
# 0 -2.25   336089.0   3842187.0             11.0       11.432052
# 0 -2.00   277843.0   2589306.0             12.0        9.319313
#
#    average weighted degree  largest component
# 0               102.046132           488506.0
# 0                85.105695           442142.0
# 0                70.482543           392744.0
# 0                57.073323           336089.0
# 0                47.017891           277843.0

# %%
db_conn_prop_df
# Out:
#   conf  num nodes   num edges  pseudo diameter  average degree  \
# 0  0.5   505326.0  14113714.0              6.0       27.929919
# 0  0.6   459781.0   8975501.0              6.0       19.521253
# 0  0.7   385827.0   5853024.0              9.0       15.170074
# 0  0.8   342799.0   4173397.0              9.0       12.174473
# 0  0.9   292811.0   2917002.0             10.0        9.962064
#
#    average weighted degree  largest component
# 0               245.473405           505326.0
# 0               180.700420           459781.0
# 0                85.981557           385827.0
# 0                67.428236           342799.0
# 0                54.166421           292811.0

# %% [markdown]
# ### Connected Graphs Plots

# %%
fel_conn_prop_df['scaled average degree'] = fel_conn_prop_df['average degree']/fel_conn_prop_df['num nodes']
fel_conn_prop_df['scaled average weighted degree'] = fel_conn_prop_df['average weighted degree']/fel_conn_prop_df['num nodes']

db_conn_prop_df['scaled average degree'] = db_conn_prop_df['average degree']/db_conn_prop_df['num nodes']
db_conn_prop_df['scaled average weighted degree'] = db_conn_prop_df['average weighted degree']/db_conn_prop_df['num nodes']

# %%
fig = plt.figure(figsize=(10,15))
ax = fig.add_subplot(111) 
ax1 = fig.add_subplot(321)
ax2 = fig.add_subplot(322)
ax3 = fig.add_subplot(323)
ax4 = fig.add_subplot(324)
ax5 = fig.add_subplot(325)
ax6 = fig.add_subplot(326)

ax.spines['top'].set_color('none')
ax.spines['bottom'].set_color('none')
ax.spines['left'].set_color('none')
ax.spines['right'].set_color('none')
ax.tick_params(labelcolor='w', top=False, bottom=False, left=False, right=False)


ax1.scatter(joint_conf_list, fel_conn_prop_df['num nodes'], label = 'FEL')
ax1.scatter(joint_conf_list, db_conn_prop_df['num nodes'], label = 'DBPedia Spotlight')
#axs[0].ylabel('fds')

ax2.scatter(joint_conf_list, fel_conn_prop_df['pseudo diameter'], label = 'FEL')
ax2.scatter(joint_conf_list, db_conn_prop_df['pseudo diameter'], label = 'DBPedia Spotlight')
ax2.legend()

ax3.scatter(joint_conf_list, fel_conn_prop_df['average degree'], label = 'FEL')
ax3.scatter(joint_conf_list, db_conn_prop_df['average degree'], label = 'DBPedia Spotlight')
#axs[0].ylabel('fds')

ax4.scatter(joint_conf_list, fel_conn_prop_df['average weighted degree'], label = 'FEL')
ax4.scatter(joint_conf_list, db_conn_prop_df['average weighted degree'], label = 'DBPedia Spotlight')

ax5.scatter(joint_conf_list, fel_conn_prop_df['scaled average degree'], label = 'FEL')
ax5.scatter(joint_conf_list, db_conn_prop_df['scaled average degree'], label = 'DBPedia Spotlight')
#axs[0].ylabel('fds')

ax6.scatter(joint_conf_list, fel_conn_prop_df['scaled average weighted degree'], label = 'FEL')
ax6.scatter(joint_conf_list, db_conn_prop_df['scaled average weighted degree'], label = 'DBPedia Spotlight')

ax1.set_ylabel("Number of nodes", fontsize = 13)
ax2.set_ylabel("Pseudodiameter", fontsize = 13)
ax3.set_ylabel("Average degree", fontsize = 13)
ax4.set_ylabel("Average weighted degree", fontsize = 13)
ax5.set_ylabel("Scaled average degree", fontsize = 13)
ax6.set_ylabel("Scaled average weighted degree", fontsize = 13)

ax.set_xlabel('Confidence', fontsize = 13, labelpad = 20)
fig.tight_layout()

# %%
fig, axs = plt.subplots(1, 2, layout='constrained', figsize=(10, 5))

ordered_conf_list = ['3', '2.75', '2.5', '2.25', '2']
for conf in ordered_conf_list:
    plot_log_deg_dist(fel_conn_graphs[conf][0], axs[0], weighted = True, label = '-' + conf)

axs[0].set_ylabel('Cumulative probability')
axs[0].set_xlabel('Weighted degree')
axs[0].legend()
axs[0].set_title('FEL')

for conf in db_conn_graphs:
    plot_log_deg_dist(db_conn_graphs[conf][0], axs[1], weighted = True, label = conf)


axs[1].set_xlabel('Weighted degree')
axs[1].set_yticks([])
axs[1].legend()
axs[1].set_title('DBPedia Spotlight')
# Out:
# Text(0.5, 1.0, 'DBPedia Spotlight')

# %%
index = ['ave local clust', 'ave global clust', 'weighted assort', 'unweighted assort']

def create_ave_prop_df(conn_graphs_dict):
    ave_prop_df = pd.DataFrame(columns = index)
    
    for graph in conn_graphs_dict:
        ave_prop_df = pd.concat([ave_prop_df, pd.Series(calc_ave_graph_values(conn_graphs_dict[graph][0]), index=index).to_frame().T], axis = 0)
    ave_prop_df['graph'] = conn_graphs_dict.keys()
    
    ave_prop_df['ave local clust val'] =ave_prop_df['ave local clust'].apply(lambda x: x[0])
    ave_prop_df['ave global clust val'] =ave_prop_df['ave global clust'].apply(lambda x: x[0])
    ave_prop_df['weighted assort val'] =ave_prop_df['weighted assort'].apply(lambda x: x[0])
    ave_prop_df['unweighted assort val'] =ave_prop_df['unweighted assort'].apply(lambda x: x[0])

    return ave_prop_df

# %%
fel_ave_prop_df = create_ave_prop_df(fel_conn_graphs)
db_ave_prop_df = create_ave_prop_df(db_conn_graphs)

# %%
fig = plt.figure(figsize=(10,10))
ax = fig.add_subplot(111)   
ax1 = fig.add_subplot(221)
ax2 = fig.add_subplot(222)
ax3 = fig.add_subplot(223)
ax4 = fig.add_subplot(224)

ax.spines['top'].set_color('none')
ax.spines['bottom'].set_color('none')
ax.spines['left'].set_color('none')
ax.spines['right'].set_color('none')
ax.tick_params(labelcolor='w', top=False, bottom=False, left=False, right=False)


ax1.scatter(joint_conf_list, fel_ave_prop_df['ave local clust val'][::-1], label = 'FEL')
ax1.scatter(joint_conf_list, db_ave_prop_df['ave local clust val'], label = 'DBpedia Spotlight')
ax1.legend()

ax2.scatter(joint_conf_list, fel_ave_prop_df['ave global clust val'][::-1], label = 'FEL')
ax2.scatter(joint_conf_list, db_ave_prop_df['ave global clust val'], label = 'DBpedia Spotlight')

ax3.scatter(joint_conf_list, fel_ave_prop_df['unweighted assort val'][::-1], label = 'FEL')
ax3.scatter(joint_conf_list, db_ave_prop_df['unweighted assort val'], label = 'DBpedia Spotlight')
#axs[0].ylabel('fds')

ax4.scatter(joint_conf_list, fel_ave_prop_df['weighted assort val'][::-1], label = 'FEL')
ax4.scatter(joint_conf_list, db_ave_prop_df['weighted assort val'], label = 'DBpedia Spotlight')

ax1.set_ylabel("Average local clustering", fontsize = 13)
ax2.set_ylabel("Average global clustering", fontsize = 13)
ax3.set_ylabel("Unweighted assortivity", fontsize = 13)
ax4.set_ylabel("Weighted assortivity", fontsize = 13)

ax.set_xlabel('Confidence', fontsize = 13, labelpad = 20)
fig.tight_layout()

# %% [markdown]
# ### Top Edges

# %%
fel_top_edges_df = pd.DataFrame()
for conf in fel_conn_graphs:
    top_edges = get_top_edges(fel_conn_graphs[conf][0],fel_conn_graphs[conf][1], 10)
    fel_top_edges_df['-' + conf] = top_edges[::-1]

# %%
cols = fel_top_edges_df.columns.tolist()
cols = cols[::-1]
fel_top_edges_df = fel_top_edges_df[cols]

# %%
fel_top_edges_df
# Out:
#                                                -3  \
# 0                                      (MTV, BTS)
# 1                               (Pfizer, Moderna)
# 2  (Ministry_of_Health_and_Family_Welfare, India)
# 3                (Bachelor_of_Science, D%C3%A9FI)
# 4                (Bachelor_of_Science, Whitelist)
# 5                           (Reblogging, Twitter)
# 6            (D%C3%A9FI, Launchpad_%28website%29)
# 7  (Bachelor_of_Science, Launchpad_%28website%29)
# 8                          (D%C3%A9FI, Whitelist)
# 9                        (Umar, Riaz_%28actor%29)
#
#                                        -2.75  \
# 0                                 (MTV, BTS)
# 1           (Bachelor_of_Science, D%C3%A9FI)
# 2           (Whitelist, Bachelor_of_Science)
# 3                     (Whitelist, D%C3%A9FI)
# 4                   (Riaz_%28actor%29, Umar)
# 5            (Metaverse, Non-fungible_token)
# 6  (Bachelor_of_Science, Non-fungible_token)
# 7              (Discord, Non-fungible_token)
# 8                            (Jungkook, BTS)
# 9          (Military_dictatorship, Mandalay)
#
#                                         -2.5  \
# 0                                 (MTV, BTS)
# 1           (Bachelor_of_Science, D%C3%A9FI)
# 2           (Whitelist, Bachelor_of_Science)
# 3                     (Whitelist, D%C3%A9FI)
# 4                            (Jungkook, BTS)
# 5            (Metaverse, Non-fungible_token)
# 6              (Discord, Non-fungible_token)
# 7                          (China, COVID-19)
# 8                               (Jimin, BTS)
# 9  (Bachelor_of_Science, Non-fungible_token)
#
#                                        -2.25  \
# 0                                 (MTV, BTS)
# 1            (Metaverse, Non-fungible_token)
# 2                               (Jimin, BTS)
# 3  (Non-fungible_token, Bachelor_of_Science)
# 4          (Mandalay, Military_dictatorship)
# 5                         (Spotify, YouTube)
# 6                            (BTS, Jungkook)
# 7                         (Netflix, Spotify)
# 8     (Netflix, Viu_%28streaming_service%29)
# 9     (Spotify, Viu_%28streaming_service%29)
#
#                                        -2
# 0                              (MTV, BTS)
# 1         (Non-fungible_token, Metaverse)
# 2                            (Jimin, BTS)
# 3                      (YouTube, Spotify)
# 4                         (Jungkook, BTS)
# 5                      (Netflix, Spotify)
# 6  (Netflix, Viu_%28streaming_service%29)
# 7  (Spotify, Viu_%28streaming_service%29)
# 8          (Non-fungible_token, MetaMask)
# 9           (Non-fungible_token, OpenSea)

# %%
db_top_edges_df = pd.DataFrame()
for conf in db_conn_graphs:
    top_edges = get_top_edges(db_conn_graphs[conf][0],db_conn_graphs[conf][1], 10)
    db_top_edges_df[conf] = top_edges[::-1]

# %%
db_top_edges_df
# Out:
#                              0.5                                        0.6  \
# 0   (COVID-19_pandemic, Twitter)               (Twitter, COVID-19_pandemic)
# 1    (Twitter, COVID-19_vaccine)                (Twitter, COVID-19_vaccine)
# 2         (Twitter, Coronavirus)                     (Coronavirus, Twitter)
# 3  (Twitter, COVID-19_lockdowns)                        (Twitter, COVID-19)
# 4            (Twitter, COVID-19)                    (Test_cricket, Twitter)
# 5          (Quarantine, Twitter)  (Twitter, President_of_the_United_States)
# 6        (Twitter, Test_cricket)                         (YouTube, Twitter)
# 7      (United_Kingdom, Twitter)                           (Virus, Twitter)
# 8               (Twitter, Virus)                           (India, Twitter)
# 9               (Twitter, India)                  (Twitter, Radiotelephone)
#
#                                             0.7  \
# 0                   (Radiotelephone, Lady_Gaga)
# 1                                    (MTV, BTS)
# 2                    (COVID-19_vaccine, Pfizer)
# 3                              (Virus, Vaccine)
# 4            (Moderna_COVID-19_vaccine, Pfizer)
# 5   (Test_cricket, India_national_cricket_team)
# 6                             (Ukraine, Russia)
# 7                  (COVID-19_vaccine, COVID-19)
# 8  (Wuhan, COVID-19_pandemic_in_mainland_China)
# 9                        (India, Narendra_Modi)
#
#                                             0.8  \
# 0                                    (BTS, MTV)
# 1                    (COVID-19_vaccine, Pfizer)
# 2            (Pfizer, Moderna_COVID-19_vaccine)
# 3   (Test_cricket, India_national_cricket_team)
# 4                             (Russia, Ukraine)
# 5  (Wuhan, COVID-19_pandemic_in_mainland_China)
# 6                  (COVID-19_vaccine, COVID-19)
# 7                        (Narendra_Modi, India)
# 8                      (Vaccine, Immune_system)
# 9                     (United_States, Mandalay)
#
#                                             0.9
# 0                                    (MTV, BTS)
# 1                    (COVID-19_vaccine, Pfizer)
# 2   (Test_cricket, India_national_cricket_team)
# 3               (COVID-19_vaccine, AstraZeneca)
# 4  (COVID-19_pandemic_in_mainland_China, Wuhan)
# 5            (Pfizer, Moderna_COVID-19_vaccine)
# 6                             (Ukraine, Russia)
# 7                     (United_States, Mandalay)
# 8                        (India, Narendra_Modi)
# 9                  (COVID-19_vaccine, COVID-19)

# %% [markdown]
# ### Top Nodes

# %%
fel_top_weighted_df = pd.DataFrame()
fel_top_unweighted_df = pd.DataFrame()
for conf in fel_conn_graphs:
    top_nodes = get_top_degree_nodes(fel_conn_graphs[conf][0],fel_conn_graphs[conf][1], 20)
    fel_top_weighted_df['-' + conf] = list(top_nodes[0].keys())
    fel_top_unweighted_df['-' + conf] = list(top_nodes[1].keys())

# %%
cols = fel_top_weighted_df.columns.tolist()
cols = cols[::-1]
fel_top_weighted_df = fel_top_weighted_df[cols]

# %%
fel_top_weighted_df
# Out:
#                                             -3  \
# 0                                     COVID-19
# 1                                      Twitter
# 2                                   Quarantine
# 3                                        India
# 4                                   Midfielder
# 5                                  Vaccination
# 6                                      YouTube
# 7                           Non-fungible_token
# 8                                        China
# 9                                          BTS
# 10                                      Pfizer
# 11                         Bachelor_of_Science
# 12                                  Reblogging
# 13                            COVID-19_vaccine
# 14                          COVID-19_lockdowns
# 15                                         LOL
# 16  Centers_for_Disease_Control_and_Prevention
# 17                           COVID-19_pandemic
# 18                                     Spotify
# 19     Face_masks_during_the_COVID-19_pandemic
#
#                                          -2.75  \
# 0                                     COVID-19
# 1                                   Quarantine
# 2                                        India
# 3                                   Midfielder
# 4                                      YouTube
# 5                                      Twitter
# 6                           Non-fungible_token
# 7                                        China
# 8                                          BTS
# 9                          Bachelor_of_Science
# 10                                  Reblogging
# 11                                     Spotify
# 12                                      Pfizer
# 13                           COVID-19_pandemic
# 14                            COVID-19_vaccine
# 15  Centers_for_Disease_Control_and_Prevention
# 16                                         LOL
# 17                                         VAX
# 18              President_of_the_United_States
# 19                                     Netflix
#
#                                -2.5                            -2.25  \
# 0                          COVID-19                          YouTube
# 1                             India                            India
# 2                           YouTube                              BTS
# 3                           Twitter                            China
# 4                               BTS                       Midfielder
# 5                             China                          Twitter
# 6                        Midfielder               Non-fungible_token
# 7                Non-fungible_token                          Spotify
# 8                           Spotify                       Reblogging
# 9               Bachelor_of_Science                           Pfizer
# 10                       Reblogging                          Netflix
# 11                           Pfizer              Bachelor_of_Science
# 12                          Netflix                              CNN
# 13                              VAX                              VAX
# 14                              CNN  This_Morning_%28TV_programme%29
# 15   President_of_the_United_States                              MTV
# 16                 COVID-19_vaccine            Military_dictatorship
# 17  This_Morning_%28TV_programme%29                         MetaMask
# 18                           Vaxxed      Viu_%28streaming_service%29
# 19                COVID-19_pandemic                          Bitcoin
#
#                                  -2
# 0                           YouTube
# 1                             India
# 2                               BTS
# 3                        Midfielder
# 4                           Twitter
# 5                           Spotify
# 6                Non-fungible_token
# 7                           Netflix
# 8                            Pfizer
# 9                               MTV
# 10                              CNN
# 11                              VAX
# 12      Viu_%28streaming_service%29
# 13  This_Morning_%28TV_programme%29
# 14                         MetaMask
# 15                          Bitcoin
# 16                        Instagram
# 17                           Vaxxed
# 18                         Fox_News
# 19                            Italy

# %%
db_top_weighted_df = pd.DataFrame()
db_top_unweighted_df = pd.DataFrame()
for conf in db_conn_graphs:
    top_nodes = get_top_degree_nodes(db_conn_graphs[conf][0],db_conn_graphs[conf][1], 20)
    db_top_weighted_df[conf] = list(top_nodes[0].keys())
    db_top_unweighted_df[conf] = list(top_nodes[1].keys())

# %%
db_top_weighted_df
# Out:
#                                                 0.5  \
# 0                                           Twitter
# 1                                 COVID-19_pandemic
# 2                                  COVID-19_vaccine
# 3                                          COVID-19
# 4                                       Coronavirus
# 5                                COVID-19_lockdowns
# 6                                             Virus
# 7                                    United_Kingdom
# 8                                        Quarantine
# 9                                             India
# 10                                     Test_cricket
# 11                   President_of_the_United_States
# 12                                          Vaccine
# 13                                    United_States
# 14                                        Joe_Biden
# 15                                            China
# 16                                   Radiotelephone
# 17  Severe_acute_respiratory_syndrome_coronavirus_2
# 18                                   Stellar_corona
# 19                                          YouTube
#
#                                                 0.6  \
# 0                                           Twitter
# 1                                 COVID-19_pandemic
# 2                                  COVID-19_vaccine
# 3                                       Coronavirus
# 4                                          COVID-19
# 5                                             Virus
# 6                    President_of_the_United_States
# 7                                      Test_cricket
# 8                                           Vaccine
# 9                                             India
# 10                                            China
# 11                                   Radiotelephone
# 12  Severe_acute_respiratory_syndrome_coronavirus_2
# 13                                          YouTube
# 14                                           Pfizer
# 15                                   Stellar_corona
# 16                               Non-fungible_token
# 17       Centers_for_Disease_Control_and_Prevention
# 18                                           Canada
# 19                                    United_States
#
#                                                 0.7  \
# 0                                  COVID-19_vaccine
# 1                                 COVID-19_pandemic
# 2                                          COVID-19
# 3                                             Virus
# 4                                      Test_cricket
# 5                                           Vaccine
# 6                                             India
# 7                                            Pfizer
# 8                                             China
# 9                                    Radiotelephone
# 10                                          Twitter
# 11                                          YouTube
# 12  Severe_acute_respiratory_syndrome_coronavirus_2
# 13                               Non-fungible_token
# 14                                           Canada
# 15                                              BTS
# 16       Centers_for_Disease_Control_and_Prevention
# 17                                           Russia
# 18                                          Ukraine
# 19                                            Delhi
#
#                           0.8                        0.9
# 0            COVID-19_vaccine           COVID-19_vaccine
# 1           COVID-19_pandemic               Test_cricket
# 2                Test_cricket                   COVID-19
# 3                    COVID-19                     Pfizer
# 4                     Vaccine          COVID-19_pandemic
# 5                      Pfizer                    Vaccine
# 6                       India                        BTS
# 7                       China                    Twitter
# 8                     Twitter                    YouTube
# 9                     YouTube                      India
# 10                        BTS                      China
# 11                     Canada                     Russia
# 12                     Russia                    Myanmar
# 13                    Ukraine                        CNN
# 14                    Myanmar                        MTV
# 15                      Delhi                      Delhi
# 16                        CNN  Impact_Wrestling_Lockdown
# 17              Narendra_Modi              Narendra_Modi
# 18  Impact_Wrestling_Lockdown                    Florida
# 19                       Iran              New_York_City
